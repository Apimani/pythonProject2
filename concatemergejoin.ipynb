# %%
import pandas as pd

# %%
df.to_csv('sales_data.csv', index=False)

# %%
df
# Out:
#    sales_id  product_id  store_id  quantity  price   sale_date region
# 0         7         107         1         4   22.0  2024-09-07   High
# 1         8         108         2         6   24.0  2024-09-08    Low
# 2         9         109         3        11   19.0  2024-09-09   High
# 3        10         110         4         9   17.0  2024-09-10    Low
# 4         1         101         1        10   15.0  2024-09-01   High
# 5         2         102         1         5   25.0  2024-09-01    Low
# 6         3         103         2         7   20.0  2024-09-02   High
# 7         4         104         2         3   30.0  2024-09-03    Low
# 8         5         105         1        12   12.0  2024-09-05   High
# 9         6         106         3         8   18.0  2024-09-06    Low

# %%
df = pd.read_csv('file.csv', usecols=['price', 'sale_date'])

# %%
df
# Out:
#    price   sale_date
# 0   22.0  2024-09-07
# 1   24.0  2024-09-08
# 2   19.0  2024-09-09
# 3   17.0  2024-09-10
# 4   15.0  2024-09-01
# 5   25.0  2024-09-01
# 6   20.0  2024-09-02
# 7   30.0  2024-09-03
# 8   12.0  2024-09-05
# 9   18.0  2024-09-06

# %%
df = pd.read_csv('file.csv', index_col='sales_id')

# %%
df
# Out:
#           Unnamed: 0  product_id  store_id  quantity  price   sale_date region
# sales_id
# 7                  0         107         1         4   22.0  2024-09-07   High
# 8                  1         108         2         6   24.0  2024-09-08    Low
# 9                  2         109         3        11   19.0  2024-09-09   High
# 10                 3         110         4         9   17.0  2024-09-10    Low
# 1                  4         101         1        10   15.0  2024-09-01   High
# 2                  5         102         1         5   25.0  2024-09-01    Low
# 3                  6         103         2         7   20.0  2024-09-02   High
# 4                  7         104         2         3   30.0  2024-09-03    Low
# 5                  8         105         1        12   12.0  2024-09-05   High
# 6                  9         106         3         8   18.0  2024-09-06    Low

# %%
df = pd.read_csv("sales_data.csv",usecols=['price','region'], index_col='price',low_memory=False)

# %%
df
# Out:
#       region
# price
# 22.0    High
# 24.0     Low
# 19.0    High
# 17.0     Low
# 15.0    High
# 25.0     Low
# 20.0    High
# 30.0     Low
# 12.0    High
# 18.0     Low

# %%
df = pd.read_csv('file.csv', dtype={'quantity': int, 'price': float})

# %%
df
# Out:
#    Unnamed: 0  sales_id  product_id  store_id  quantity  price   sale_date  \
# 0           0         7         107         1         4   22.0  2024-09-07
# 1           1         8         108         2         6   24.0  2024-09-08
# 2           2         9         109         3        11   19.0  2024-09-09
# 3           3        10         110         4         9   17.0  2024-09-10
# 4           4         1         101         1        10   15.0  2024-09-01
# 5           5         2         102         1         5   25.0  2024-09-01
# 6           6         3         103         2         7   20.0  2024-09-02
# 7           7         4         104         2         3   30.0  2024-09-03
# 8           8         5         105         1        12   12.0  2024-09-05
# 9           9         6         106         3         8   18.0  2024-09-06
#
#   region
# 0   High
# 1    Low
# 2   High
# 3    Low
# 4   High
# 5    Low
# 6   High
# 7    Low
# 8   High
# 9    Low

# %%
for chunk in pd.read_csv('sale_data.csv', chunksize=1000):
    print(chunk)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 for chunk in pd.read_csv('sale_data.csv', chunksize=1000):
#       2     print(chunk)
#
# File ~\PycharmProjects\pythonProject2\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
iterator = pd.read_csv('file.csv', iterator=True, chunksize=1000)

# %%
iterator

# %%
df = pd.read_csv('file.csv', memory_map=True)

# %%
df
# Out:
#    Unnamed: 0  sales_id  product_id  store_id  quantity  price   sale_date  \
# 0           0         7         107         1         4   22.0  2024-09-07
# 1           1         8         108         2         6   24.0  2024-09-08
# 2           2         9         109         3        11   19.0  2024-09-09
# 3           3        10         110         4         9   17.0  2024-09-10
# 4           4         1         101         1        10   15.0  2024-09-01
# 5           5         2         102         1         5   25.0  2024-09-01
# 6           6         3         103         2         7   20.0  2024-09-02
# 7           7         4         104         2         3   30.0  2024-09-03
# 8           8         5         105         1        12   12.0  2024-09-05
# 9           9         6         106         3         8   18.0  2024-09-06
#
#   region
# 0   High
# 1    Low
# 2   High
# 3    Low
# 4   High
# 5    Low
# 6   High
# 7    Low
# 8   High
# 9    Low

# %%
df = pd.read_csv('file.csv', parse_dates=['date_column'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 df = pd.read_csv('file.csv', parse_dates=['date_column'])
#
# File ~\PycharmProjects\pythonProject2\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df = pd.read_csv('file.csv', skiprows=10)

# %%
df
# Out:
# Empty DataFrame
# Columns: [9, 6, 106, 3, 8, 18.0, 2024-09-06, Low]
# Index: []

# %%
df = pd.read_csv('file.csv', header=1)

# %%
df
# Out:
#    0   7  107  1   4  22.0  2024-09-07  High
# 0  1   8  108  2   6  24.0  2024-09-08   Low
# 1  2   9  109  3  11  19.0  2024-09-09  High
# 2  3  10  110  4   9  17.0  2024-09-10   Low
# 3  4   1  101  1  10  15.0  2024-09-01  High
# 4  5   2  102  1   5  25.0  2024-09-01   Low
# 5  6   3  103  2   7  20.0  2024-09-02  High
# 6  7   4  104  2   3  30.0  2024-09-03   Low
# 7  8   5  105  1  12  12.0  2024-09-05  High
# 8  9   6  106  3   8  18.0  2024-09-06   Low

# %%
df = pd.read_csv('file.csv', names=['A', 'B', 'C'])

# %%
df
# Out:
#                                                A           B       C
# NaN sales_id product_id store_id quantity  price   sale_date  region
# 0.0 7        107        1        4          22.0  2024-09-07    High
# 1.0 8        108        2        6          24.0  2024-09-08     Low
# 2.0 9        109        3        11         19.0  2024-09-09    High
# 3.0 10       110        4        9          17.0  2024-09-10     Low
# 4.0 1        101        1        10         15.0  2024-09-01    High
# 5.0 2        102        1        5          25.0  2024-09-01     Low
# 6.0 3        103        2        7          20.0  2024-09-02    High
# 7.0 4        104        2        3          30.0  2024-09-03     Low
# 8.0 5        105        1        12         12.0  2024-09-05    High
# 9.0 6        106        3        8          18.0  2024-09-06     Low

# %%
df = pd.read_csv('file.csv', skiprows=5, nrows=5)

# %%
df
# Out:
#    4  1  101  1.1  10  15.0  2024-09-01  High
# 0  5  2  102    1   5  25.0  2024-09-01   Low
# 1  6  3  103    2   7  20.0  2024-09-02  High
# 2  7  4  104    2   3  30.0  2024-09-03   Low
# 3  8  5  105    1  12  12.0  2024-09-05  High
# 4  9  6  106    3   8  18.0  2024-09-06   Low

# %%
df_full = pd.read_csv('file.csv')

# %%
df_full
# Out:
#    Unnamed: 0  sales_id  product_id  store_id  quantity  price   sale_date  \
# 0           0         7         107         1         4   22.0  2024-09-07
# 1           1         8         108         2         6   24.0  2024-09-08
# 2           2         9         109         3        11   19.0  2024-09-09
# 3           3        10         110         4         9   17.0  2024-09-10
# 4           4         1         101         1        10   15.0  2024-09-01
# 5           5         2         102         1         5   25.0  2024-09-01
# 6           6         3         103         2         7   20.0  2024-09-02
# 7           7         4         104         2         3   30.0  2024-09-03
# 8           8         5         105         1        12   12.0  2024-09-05
# 9           9         6         106         3         8   18.0  2024-09-06
#
#   region
# 0   High
# 1    Low
# 2   High
# 3    Low
# 4   High
# 5    Low
# 6   High
# 7    Low
# 8   High
# 9    Low

# %%
df = df_full.iloc[5:10]

# %%
df
# Out:
#    Unnamed: 0  sales_id  product_id  store_id  quantity  price   sale_date  \
# 5           5         2         102         1         5   25.0  2024-09-01
# 6           6         3         103         2         7   20.0  2024-09-02
# 7           7         4         104         2         3   30.0  2024-09-03
# 8           8         5         105         1        12   12.0  2024-09-05
# 9           9         6         106         3         8   18.0  2024-09-06
#
#   region
# 5    Low
# 6   High
# 7    Low
# 8   High
# 9    Low

# %%
data = {'A': [2, 1, 3], 'B': [5, 6, 7]}
df = pd.DataFrame(data)

# %%
df
# Out:
#    A  B
# 0  2  5
# 1  1  6
# 2  3  7

# %%
df_sorted = df.sort_values(by='A')

# %%
df_sorted
# Out:
#    A  B
# 1  1  6
# 0  2  5
# 2  3  7

# %%
data = {'A': [2, 1, 3, 2], 'B': [5, 6, 7, 4]}
df = pd.DataFrame(data)

# %%
df
# Out:
#    A  B
# 0  2  5
# 1  1  6
# 2  3  7
# 3  2  4

# %%
df_sorted = df.sort_values(by=['A', 'B'])

# %%
df_sorted
# Out:
#    A  B
# 1  1  6
# 3  2  4
# 0  2  5
# 2  3  7

# %%
data = {'A': [2, 1, 3], 'B': [5, 6, 7]}
df = pd.DataFrame(data)

# %%
df
# Out:
#    A  B
# 0  2  5
# 1  1  6
# 2  3  7

# %%
df_sorted = df.sort_values(by='A', ascending=False)

# %%
df_sorted
# Out:
#    A  B
# 2  3  7
# 0  2  5
# 1  1  6

# %%
data = {'A': [2, 1, 3, 2], 'B': [5, 6, 7, 4]}
df = pd.DataFrame(data)

# %%
df_sorted = df.sort_values(by=['A', 'B'], ascending=[True, False])

# %%
df_sorted
# Out:
#    A  B
# 1  1  6
# 0  2  5
# 3  2  4
# 2  3  7

# %%
data = {'A': [2, 1, 3], 'B': [5, 6, 7]}
df = pd.DataFrame(data, index=[2, 1, 3])

# %%
df_sorted = df.sort_index()

# %%
df_sorted
# Out:
#    A  B
# 1  1  6
# 2  2  5
# 3  3  7

# %%
data = {'A': [2, 1, 3], 'B': [5, 6, 7]}
df = pd.DataFrame(data)

# %%
aa=df.sort_values(by='A', inplace=True)

# %%
aa

# %%
data = {'Category': ['A', 'B', 'A', 'B', 'A'],
'Values': [10, 20, 30, 40, 50]}
df = pd.DataFrame(data)

# %%
df
# Out:
#   Category  Values
# 0        A      10
# 1        B      20
# 2        A      30
# 3        B      40
# 4        A      50

# %%
grouped = df.groupby('Category')['Values'].sum()
print(grouped)
# Out:
# Category
# A    90
# B    60
# Name: Values, dtype: int64

# %%
data = {'Category': ['A', 'B', 'A', 'B', 'A'],
'Type': ['X', 'X', 'Y', 'Y', 'Y'],
'Values': [10, 20, 30, 40, 50]}
df = pd.DataFrame(data)

# %%
df
# Out:
#   Category Type  Values
# 0        A    X      10
# 1        B    X      20
# 2        A    Y      30
# 3        B    Y      40
# 4        A    Y      50

# %%
grouped = df.groupby(['Category', 'Type'])['Values'].sum()
print(grouped)
# Out:
# Category  Type
# A         X       10
#           Y       80
# B         X       20
#           Y       40
# Name: Values, dtype: int64

# %%
data = {'Category': ['A', 'B', 'A', 'B', 'A'],
'Values': [10, 20, 30, 40, 50]}
df = pd.DataFrame(data)

# %%
df
# Out:
#   Category  Values
# 0        A      10
# 1        B      20
# 2        A      30
# 3        B      40
# 4        A      50

# %%
grouped = df.groupby('Category')['Values'].agg(['sum', 'mean'])
print(grouped)
# Out:
#           sum  mean
# Category
# A          90  30.0
# B          60  30.0

# %%
data = {'Category': ['A', 'B', 'A', 'B', 'A'],
'Values': [10, 20, 30, 40, 50]}
df = pd.DataFrame(data)

# %%
df
# Out:
#   Category  Values
# 0        A      10
# 1        B      20
# 2        A      30
# 3        B      40
# 4        A      50

# %%
filtered = df.groupby('Category').filter(lambda x: x['Values'].sum() > 60)
print(filtered)
# Out:
#   Category  Values
# 0        A      10
# 2        A      30
# 4        A      50

# %%
df1 = pd.DataFrame({'A': [1, 2], 'B': [3, 4]})
df2 = pd.DataFrame({'A': [5, 6], 'B': [7, 8]})

# %%
df1
# Out:
#    A  B
# 0  1  3
# 1  2  4

# %%
df2
# Out:
#    A  B
# 0  5  7
# 1  6  8

# %%
result = pd.concat([df1, df2])

# %%
result
# Out:
#    A  B
# 0  1  3
# 1  2  4
# 0  5  7
# 1  6  8

# %%
df1 = pd.DataFrame({'A': [1, 2]})
df2 = pd.DataFrame({'B': [3, 4]})

# %%
df1
# Out:
#    A
# 0  1
# 1  2

# %%
df2
# Out:
#    B
# 0  3
# 1  4

# %%
result = pd.concat([df1, df2], axis=1)

# %%
result
# Out:
#    A  B
# 0  1  3
# 1  2  4

# %%
df1 = pd.DataFrame({'A': [1, 2]})
df2 = pd.DataFrame({'B': [3, 4]})

# %%
df1
# Out:
#    A
# 0  1
# 1  2

# %%
df2
# Out:
#    B
# 0  3
# 1  4

# %%
result = pd.concat([df1, df2], axis=0, join='outer')

# %%
result
# Out:
#      A    B
# 0  1.0  NaN
# 1  2.0  NaN
# 0  NaN  3.0
# 1  NaN  4.0

# %%
python -m pip install sqlalchemy
# Out:
#   Cell In[111], line 1
#     python -m pip install sqlalchemy
#               ^
# SyntaxError: invalid syntax

# %%
from sqlalchemy import create_engine
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[112], line 1
# ----> 1 from sqlalchemy import create_engine
#       2 import pandas as pd
#
# ModuleNotFoundError: No module named 'sqlalchemy'

# %%
data = {'Category': ['A', 'B', 'A', 'B', 'A'],
'Values': [10, 20, 30, 40, 50]}
df = pd.DataFrame(data)

# %%
df
# Out:
#   Category  Values
# 0        A      10
# 1        B      20
# 2        A      30
# 3        B      40
# 4        A      50

# %%
grouped = df.groupby('Category')['Values'].sum()
print(grouped)
# Out:
# Category
# A    90
# B    60
# Name: Values, dtype: int64

# %%
data = {'Category': ['A', 'B', 'A', 'B', 'A'],
'Type': ['X', 'X', 'Y', 'Y', 'Y'],
'Values': [10, 20, 30, 40, 50]}
df = pd.DataFrame(data)

# %%
df
# Out:
#   Category Type  Values
# 0        A    X      10
# 1        B    X      20
# 2        A    Y      30
# 3        B    Y      40
# 4        A    Y      50

# %%
grouped = df.groupby(['Category', 'Type'])['Values'].sum()
print(grouped)
# Out:
# Category  Type
# A         X       10
#           Y       80
# B         X       20
#           Y       40
# Name: Values, dtype: int64

# %%
grouped = df.groupby('Category')['Values'].agg(['sum', 'mean'])
print(grouped)
# Out:
#           sum  mean
# Category
# A          90  30.0
# B          60  30.0

# %%
grouped.rename(columns={Category:
'Categorization','sum':'total_salary',mean:"average"},inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[123], line 1
# ----> 1 grouped.rename(columns={Category:
#       2 'Categorization','sum':'total_salary',mean:"average"},inplace=True)
#
# NameError: name 'Category' is not defined

# %%
grouped.rename(columns={'category': 'Categorization', 'sum': 'total_salary', 'mean': 'average'}, inplace=True)

# %%
print(grouped)
# Out:
#           total_salary  average
# Category
# A                   90     30.0
# B                   60     30.0

# %%
data = {'numbers': [1, 2, 3, 4, 5]}
df = pd.DataFrame(data)

# %%
df
# Out:
#    numbers
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5

# %%
df['doubled'] = df['numbers'].apply(lambda x: x * 2)
print(df)
# Out:
#    numbers  doubled
# 0        1        2
# 1        2        4
# 2        3        6
# 3        4        8
# 4        5       10

# %%
s = pd.Series(['cat', 'dog', 'bird'])

# %%
s = s.map(lambda x: x.upper())
print(s)
# Out:
# 0     CAT
# 1     DOG
# 2    BIRD
# dtype: object

# %%
data = {
"name": ["Mayank", "Rajesh", "Shiva"],
"age": [40, 60, 30],
"qualified": [True, False, False]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#      name  age  qualified
# 0  Mayank   40       True
# 1  Rajesh   60      False
# 2   Shiva   30      False

# %%
filtered_df = df.filter(items=["name", "age"])

# %%
filtered_df
# Out:
#      name  age
# 0  Mayank   40
# 1  Rajesh   60
# 2   Shiva   30

# %%
filtered_df = df.filter(items=[0,1],axis=0)

# %%
filtered_df
# Out:
#      name  age  qualified
# 0  Mayank   40       True
# 1  Rajesh   60      False

# %%
data = {
"eno": [1,2,3,4,5],
"ename": ['A','B','C','D','E']
}

# %%
emp = pd.DataFrame(data)

# %%
emp
# Out:
#    eno ename
# 0    1     A
# 1    2     B
# 2    3     C
# 3    4     D
# 4    5     E

# %%
data = {
    'eno':[1,2,3,6,7],
    'sal':[1000,1500,2000,3000,3000]
}

# %%
sal = pd.DataFrame(data)

# %%
sal
# Out:
#    eno   sal
# 0    1  1000
# 1    2  1500
# 2    3  2000
# 3    6  3000
# 4    7  3000

# %%
emp.to_csv('emp.csv')

# %%
sal.to_csv('sal.csv')

# %%
df1 = pd.read_csv('emp.csv')

# %%
df1
# Out:
#    Unnamed: 0  eno ename
# 0           0    1     A
# 1           1    2     B
# 2           2    3     C
# 3           3    4     D
# 4           4    5     E

# %%
df2 = pd.read_csv('sal.csv')

# %%
df2
# Out:
#    Unnamed: 0  eno   sal
# 0           0    1  1000
# 1           1    2  1500
# 2           2    3  2000
# 3           3    6  3000
# 4           4    7  3000

# %%
df1 = pd.read_csv('emp.csv')

# %%
df1.merge(df2,on='eno',how='inner')
# Out:
#    Unnamed: 0_x  eno ename  Unnamed: 0_y   sal
# 0             0    1     A             0  1000
# 1             1    2     B             1  1500
# 2             2    3     C             2  2000

# %%
df1.merge(df2,on='eno',how='outer')
# Out:
#    Unnamed: 0_x  eno ename  Unnamed: 0_y     sal
# 0           0.0    1     A           0.0  1000.0
# 1           1.0    2     B           1.0  1500.0
# 2           2.0    3     C           2.0  2000.0
# 3           3.0    4     D           NaN     NaN
# 4           4.0    5     E           NaN     NaN
# 5           NaN    6   NaN           3.0  3000.0
# 6           NaN    7   NaN           4.0  3000.0

# %%
df1.merge(df2,on='eno',how='left')
# Out:
#    Unnamed: 0_x  eno ename  Unnamed: 0_y     sal
# 0             0    1     A           0.0  1000.0
# 1             1    2     B           1.0  1500.0
# 2             2    3     C           2.0  2000.0
# 3             3    4     D           NaN     NaN
# 4             4    5     E           NaN     NaN

# %%
df1.merge(df2,on='eno',how='right')
# Out:
#    Unnamed: 0_x  eno ename  Unnamed: 0_y   sal
# 0           0.0    1     A             0  1000
# 1           1.0    2     B             1  1500
# 2           2.0    3     C             2  2000
# 3           NaN    6   NaN             3  3000
# 4           NaN    7   NaN             4  3000

# %%
result = pd.concat([df1, df2], axis=0)

# %%
result
# Out:
#    Unnamed: 0  eno ename     sal
# 0           0    1     A     NaN
# 1           1    2     B     NaN
# 2           2    3     C     NaN
# 3           3    4     D     NaN
# 4           4    5     E     NaN
# 0           0    1   NaN  1000.0
# 1           1    2   NaN  1500.0
# 2           2    3   NaN  2000.0
# 3           3    6   NaN  3000.0
# 4           4    7   NaN  3000.0

# %%
result = pd.concat([df1, df2], axis=1)

# %%
result
# Out:
#    Unnamed: 0  eno ename  Unnamed: 0  eno   sal
# 0           0    1     A           0    1  1000
# 1           1    2     B           1    2  1500
# 2           2    3     C           2    3  2000
# 3           3    4     D           3    6  3000
# 4           4    5     E           4    7  3000
